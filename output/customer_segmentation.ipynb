# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

import os

# %%
INPUT_DIR = "."
OUTPUT_DIR = "."
CHART_DIR = os.path.join(OUTPUT_DIR, "charts")

rfm_path = os.path.join(INPUT_DIR, "rfm_table.csv")

print("Looking in:", os.path.abspath(INPUT_DIR))
print("Files here:", os.listdir(INPUT_DIR))

if not os.path.exists(rfm_path):
    raise FileNotFoundError(
        f"Could not find '{rfm_path}'. Current dir: {os.getcwd()}. "
        f"Files present: {os.listdir('.')}\n\n"
        f"Fix: run 02_eda_analysis.ipynb first - it creates rfm_table.csv, "
        f"which this notebook depends on."
    )

os.makedirs(CHART_DIR, exist_ok=True)
sns.set_theme(style="whitegrid")

rfm = pd.read_csv(rfm_path)
print(f"\nLoaded {len(rfm)} customers.")
rfm.head()
# Out:
# Looking in: c:\Users\Lenovo\OneDrive\Desktop\E-CommerceSales\output
# Files here: ['audit_trail.csv', 'charts', 'cleaned_sales.csv', 'customer_segmentation.ipynb', 'eda_analysis.ipynb', 'excluded_rows.csv', 'non_product_transactions.csv', 'returns.csv', 'rfm_table.csv']
#
# Loaded 4334 customers.
#    CustomerID  Recency  Frequency  Monetary  R_Score  F_Score  M_Score  \
# 0       12346      326          1  77183.60        1        1        4
# 1       12347        2          7   4310.00        4        4        4
# 2       12348       75          4   1437.24        2        3        3
# 3       12349       19          1   1457.55        3        1        3
# 4       12350      310          1    294.40        1        1        1
#
#    RFM_Segment         Segment_Label
# 0          114        Lost / Dormant
# 1          444             Champions
# 2          233  At Risk (high value)
# 3          313       New / Promising
# 4          111        Lost / Dormant

# %% [markdown]
# **PREPARING FEATURES**

# %% [markdown]
# K-Means uses Euclidean distance, so
